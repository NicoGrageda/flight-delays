# %% [markdown]
# # Trabajo de Juan

# %% [markdown]
# ## Problema
#
# El problema consiste en predecir la probabilidad de atraso de los vuelos que aterrizan o despegan del aeropuerto de Santiago
# de Chile (SCL). Para eso les entregamos un dataset usando datos públicos y reales donde cada fila corresponde a un vuelo
# que aterrizó o despegó de SCL. Para cada vuelo se cuenta con la siguiente información:
#
# * **Fecha-I** : Fecha y hora programada del vuelo.
# * **Vlo-I** : Número de vuelo programado.
# * **Ori-I** : Código de ciudad de origen programado.
# * **Des-I** : Código de ciudad de destino programado.
# * **Emp-I** : Código aerolínea de vuelo programado.
# * **Fecha-O** : Fecha y hora de operación del vuelo.
# * **Vlo-O** : Número de vuelo de operación del vuelo.
# * **Ori-O** : Código de ciudad de origen de operación
# * **Des-O** : Código de ciudad de destino de operación.
# * **Emp-O** : Código aerolínea de vuelo operado.
# * **DIA** : Día del mes de operación del vuelo.
# * **MES** : Número de mes de operación del vuelo.
# * **AÑO** : Año de operación del vuelo.
# * **DIANOM** : Día de la semana de operación del vuelo.
# * **TIPOVUELO** : Tipo de vuelo, I =Internacional, N =Nacional.
# * **OPERA** : Nombre de aerolínea que opera.
# * **SIGLAORI** : Nombre ciudad origen.
# * **SIGLADES** : Nombre ciudad destino.

# %% [markdown]
# ## Desarrollo

# %% [markdown]
# ### 0. Obtención de datos

# %%
#Se importan las librerías necesarias para el problema
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import missingno as msng
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 10)

# %%
df = pd.read_csv('dataset_SCL.csv')

# %%
df.shape
# Out:
# (68206, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68206 entries, 0 to 68205
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Fecha-I    68206 non-null  object
#  1   Vlo-I      68206 non-null  object
#  2   Ori-I      68206 non-null  object
#  3   Des-I      68206 non-null  object
#  4   Emp-I      68206 non-null  object
#  5   Fecha-O    68206 non-null  object
#  6   Vlo-O      68205 non-null  object
#  7   Ori-O      68206 non-null  object
#  8   Des-O      68206 non-null  object
#  9   Emp-O      68206 non-null  object
#  10  DIA        68206 non-null  int64
#  11  MES        68206 non-null  int64
#  12  AÑO        68206 non-null  int64
#  13  DIANOM     68206 non-null  object
#  14  TIPOVUELO  68206 non-null  object
#  15  OPERA      68206 non-null  object
#  16  SIGLAORI   68206 non-null  object
#  17  SIGLADES   68206 non-null  object
# dtypes: int64(3), object(15)
# memory usage: 9.4+ MB

# %%
msng.matrix(df)
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#                 DIA           MES           AÑO
# count  68206.000000  68206.000000  68206.000000
# mean      15.714790      6.622585   2017.000029
# std        8.782886      3.523321      0.005415
# min        1.000000      1.000000   2017.000000
# 25%        8.000000      3.000000   2017.000000
# 50%       16.000000      7.000000   2017.000000
# 75%       23.000000     10.000000   2017.000000
# max       31.000000     12.000000   2018.000000

# %% [markdown]
# ### 1. ¿Cómo se distribuyen los datos? ¿Qué te llama la atención o cuál es tu conclusión sobre esto?

# %%
vuelos_aerolineas = df['OPERA'].value_counts()
plt.figure(figsize = (10,6))
sns.set(style="darkgrid")
sns.barplot(x=vuelos_aerolineas.index, y=vuelos_aerolineas.values, alpha=0.9)
plt.title('Cantidad de Vuelos por Aerlínea')
plt.ylabel('Número de Vuelos', fontsize=12)
plt.xlabel('Aerlínea', fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %%
vuelos_dia = df['DIA'].value_counts()
plt.figure(figsize = (10,6))
sns.set(style = "darkgrid")
sns.barplot(x=vuelos_dia.index, y=vuelos_dia.values, color = 'lightblue', alpha=0.8)
plt.title('Cantidad de Vuelos por día del Mes')
plt.ylabel('Número de Vuelos', fontsize=12)
plt.xlabel('Día del Mes', fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %%
vuelos_mes = df['MES'].value_counts()
sns.set(style = "darkgrid")
sns.barplot(x=vuelos_mes.index, y=vuelos_mes.values, color = 'lightblue', alpha=0.8)
plt.title('Cantidad de Vuelos por día del Mes')
plt.ylabel('Número de Vuelos', fontsize=12)
plt.xlabel('Día del Mes', fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %%
vuelos = df['DIANOM'].value_counts()
dias = [vuelos.index[2], vuelos.index[5], vuelos.index[4], vuelos.index[1], vuelos.index[0], vuelos.index[6], vuelos.index[3]]
valores_dias = [vuelos.values[2], vuelos.values[5], vuelos.values[4], vuelos.values[1], vuelos.values[0], vuelos.values[6], vuelos.values[3]]

sns.set(style="darkgrid")
sns.barplot(x=dias, y=valores_dias, color = 'lightblue', alpha=0.8)
plt.title('Cantidad de Vuelos por Día de la Semana')
plt.ylabel('Número de Vuelos', fontsize=12)
plt.xlabel('Día de la Semana', fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %%
vuelos = df['TIPOVUELO'].value_counts()
sns.set(style="darkgrid")
sns.barplot(x=vuelos.index, y=vuelos.values, alpha=0.9)
plt.title('Cantidad de Vuelos por Tipo de Vuelo')
plt.ylabel('Número de Vuelos', fontsize=12)
plt.xlabel('Tipo de Vuelo', fontsize=12)
plt.show()

# %%
vuelos = df['SIGLADES'].value_counts()
sns.set(style="darkgrid")
sns.barplot(x=vuelos.index, y=vuelos.values, color = 'lightblue', alpha=0.8)
plt.title('Cantidad de Vuelos por Destino')
plt.ylabel('Número de Vuelos', fontsize=12)
plt.xlabel('Destino', fontsize=12)
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# Respecto a las distribuciones, se puede ver que dentro de todo la data está distribuida de manera bastante balanceada. De todas formas se pueden notar ciertas particularidades en algunas columnas:
# * En las aerolíneas LATAM Airlines es la con mayor cantidad de vuelo debido a que es la más grande aquí en chile y es la que tiene mayor cantidad de destinos. SKY Airlines sería la segunda más grande y de ahí en adelante las demás son bastante similares en cuanto a vuelos.
# * En cuanto a los días del mes, se puede ver como el día 31 tiene menor cantidad que los demás días y esto se puede deber a que hay menos días 31 durante el año.
# * Con los días de semana, el día sábado es el único en el que se nota una diferencia. Aquí puede ser porque la gente prefiere ese día para quedarse en donde sea que esté y aprovecharlo en caso que esté de viaje para poder recorrer o solamente descansar.
# * Por parte de los destinos se puede ver que gran parte se lo llevan las ciudades chilenas del norte. Esto puede ser por un alto flujo en minería.

# %% [markdown]
# ### 2. Genera las columnas adicionales y luego expórtelas en un archivo synthetic_features.csv :

# %% [markdown]
# * **temporada_alta** : 1 si **Fecha-I** está entre 15-Dic y 3-Mar, o 15-Jul y 31-Jul, o 11-Sep y 30-Sep, 0 si no

# %%
from datetime import datetime

def temporada_alta(fecha):
    fecha_año = int(fecha.split('-')[0])
    fecha = datetime.strptime(fecha, '%Y-%m-%d %H:%M:%S')
    range1_min = datetime.strptime('15-Dec', '%d-%b').replace(year = fecha_año)
    range1_max = datetime.strptime('31-Dec', '%d-%b').replace(year = fecha_año)
    range2_min = datetime.strptime('1-Jan', '%d-%b').replace(year = fecha_año)
    range2_max = datetime.strptime('3-Mar', '%d-%b').replace(year = fecha_año)
    range3_min = datetime.strptime('15-Jul', '%d-%b').replace(year = fecha_año)
    range3_max = datetime.strptime('31-Jul', '%d-%b').replace(year = fecha_año)
    range4_min = datetime.strptime('11-Sep', '%d-%b').replace(year = fecha_año)
    range4_max = datetime.strptime('30-Sep', '%d-%b').replace(year = fecha_año)
    
    if ((fecha >= range1_min and fecha <= range1_max) or 
        (fecha >= range2_min and fecha <= range2_max) or 
        (fecha >= range3_min and fecha <= range3_max) or
        (fecha >= range4_min and fecha <= range4_max)):
        return 1
    else:
        return 0

# %%
df['temporada_alta'] = df['Fecha-I'].apply(temporada_alta)

# %%
df['temporada_alta'].value_counts()
# Out:
# 0    46174
# 1    22032
# Name: temporada_alta, dtype: int64

# %% [markdown]
# * **dif_min** : diferencia en minutos entre **Fecha-O** y **Fecha-I** .

# %%
def dif_min(data):
    fecha_o = datetime.strptime(data['Fecha-O'], '%Y-%m-%d %H:%M:%S')
    fecha_i = datetime.strptime(data['Fecha-I'], '%Y-%m-%d %H:%M:%S')
    dif_min = ((fecha_o - fecha_i).total_seconds())/60
    return dif_min

# %%
df['dif_min'] = df.apply(dif_min, axis = 1)

# %% [markdown]
# * **atraso_15** : 1 si **dif_min** > 15, 0 si no.

# %%
df['atraso_15'] = np.where(df['dif_min'] > 15, 1, 0)

# %%
df['atraso_15'].value_counts()
# Out:
# 0    55592
# 1    12614
# Name: atraso_15, dtype: int64

# %% [markdown]
# * **periodo_dia** : mañana (entre 5:00 y 11:59), tarde (entre 12:00 y 18:59) y noche (entre 19:00 y 4:59), en base a **Fecha-I**.

# %%
def get_periodo_dia(fecha):
    fecha_time = datetime.strptime(fecha, '%Y-%m-%d %H:%M:%S').time()
    mañana_min = datetime.strptime("05:00", '%H:%M').time()
    mañana_max = datetime.strptime("11:59", '%H:%M').time()
    tarde_min = datetime.strptime("12:00", '%H:%M').time()
    tarde_max = datetime.strptime("18:59", '%H:%M').time()
    noche_min1 = datetime.strptime("19:00", '%H:%M').time()
    noche_max1 = datetime.strptime("23:59", '%H:%M').time()
    noche_min2 = datetime.strptime("00:00", '%H:%M').time()
    noche_max2 = datetime.strptime("4:59", '%H:%M').time()
    
    if(fecha_time > mañana_min and fecha_time < mañana_max):
        return 'mañana'
    elif(fecha_time > tarde_min and fecha_time < tarde_max):
        return 'tarde'
    elif((fecha_time > noche_min1 and fecha_time < noche_max1) or
         (fecha_time > noche_min2 and fecha_time < noche_max2)):
        return 'noche'

# %%
df['periodo_dia'] = df['Fecha-I'].apply(get_periodo_dia)

# %%
df[['temporada_alta','dif_min','atraso_15','periodo_dia']].to_csv('synthetic_features.csv', index = False)

# %% [markdown]
# ### 3. ¿Cómo se compone la tasa de atraso por destino, aerolínea, mes del año, día de la semana, temporada, tipo de vuelo? ¿Qué variables esperarías que más influyeran en predecir atrasos?

# %% [markdown]
# * ¿Cómo se compone la tasa de atraso por destino, aerolínea, mes del año, día de la semana, temporada, tipo de vuelo?

# %%
#Se observa que esta función es ineficiente, se crea una versión optimizada
def calcular_tasaV1(df, columna):
    
    dic_atrasos = {}
    for _, row in df.iterrows():
        if row['atraso_15'] == 1:
            if row[columna] not in dic_atrasos:
                dic_atrasos[row[columna]] = 1
            else:
                dic_atrasos[row[columna]] += 1
    
    total_values = df[columna].value_counts()
    
    dic_tasas = {}
    for name, total in total_values.iteritems():
        if name in dic_atrasos:
            dic_tasas[name] = round( dic_atrasos[name]/total, 2)*100
        else:
            dic_tasas[name] = 0
            
    return pd.DataFrame.from_dict(data = dic_tasas, orient = 'index', columns = ['Tasa (%)'])

def calcular_tasa(df, columna):
    atrasos=df[df["atraso_15"]==1]
    total_atrasos=atrasos[columna].value_counts() #total de vuelos atrasado por elemento de la columna
    
    total_values = df[columna].value_counts() #total de vuelos por elementto de la columna
    
    dic_tasas = {}
    for name, total in total_values.iteritems():
        if name in total_atrasos.index:
            dic_tasas[name] = round( total_atrasos[name]/total, 2)*100
        else:
            dic_tasas[name] = 0
            
    return pd.DataFrame.from_dict(data = dic_tasas, orient = 'index', columns = ['Tasa (%)'])

# %%
tasas_destinos = calcular_tasa(df, 'SIGLADES')
tasas_destinos
# Out:
#                 Tasa (%)
# Buenos Aires        26.0
# Antofagasta         15.0
# Lima                23.0
# Calama              12.0
# Puerto Montt        17.0
# ...                  ...
# Quito              100.0
# Washington           0.0
# Pisco, Peru          0.0
# Cochabamba         100.0
# Puerto Stanley     100.0
#
# [62 rows x 1 columns]

# %%
tasas_destinos_values = df['SIGLADES'].value_counts().index
plt.figure(figsize = (20,5))
sns.set(style="darkgrid")
sns.barplot(x=df['SIGLADES'].value_counts().index, y=tasas_destinos['Tasa (%)'], alpha = 0.75)
plt.title('Tasa de Retraso por Destino')
plt.ylabel('Tasa de Retraso [%]', fontsize=12)
plt.xlabel('Destino', fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %%
tasas_aerolineas = calcular_tasa(df, 'OPERA')
tasas_aerolineas
# Out:
#                           Tasa (%)
# Grupo LATAM                   18.0
# Sky Airline                   18.0
# Aerolineas Argentinas         24.0
# Copa Air                       6.0
# Latin American Wings          41.0
# Avianca                       27.0
# JetSmart SPA                  18.0
# Gol Trans                     36.0
# American Airlines              7.0
# Air Canada                    46.0
# Iberia                        10.0
# Delta Air                      6.0
# Air France                     8.0
# Aeromexico                     3.0
# United Airlines                5.0
# Oceanair Linhas Aereas        15.0
# Alitalia                      11.0
# K.L.M.                         8.0
# British Airways               14.0
# Qantas Airways                58.0
# Lacsa                         12.0
# Austral                       20.0
# Plus Ultra Lineas Aereas      61.0

# %%
tasas_aerolineas_values = df['OPERA'].value_counts().index

plt.figure(figsize = (10,5))
sns.set(style="darkgrid")
sns.barplot(x=tasas_aerolineas_values, y=tasas_aerolineas['Tasa (%)'], alpha = 0.75)
plt.title('Tasa de Retraso por Aerlínea')
plt.ylabel('Tasa de Retraso [%]', fontsize=12)
plt.xlabel('Aerolínea', fontsize=12)
plt.xticks(rotation=90)
plt.show()

# %%
tasas_meses = calcular_tasa(df, 'MES')
tasas_meses
# Out:
#     Tasa (%)
# 12      25.0
# 1       16.0
# 11      20.0
# 10      23.0
# 7       29.0
# 8       17.0
# 9       17.0
# 2       15.0
# 3       12.0
# 5       16.0
# 4       12.0
# 6       17.0

# %%
tasas_meses_values = df['MES'].value_counts().index

plt.figure(figsize = (10,5))
sns.set(style="darkgrid")
sns.barplot(x=tasas_meses_values, y=tasas_meses['Tasa (%)'], color = 'blue', alpha = 0.75)
plt.title('Tasa de Retraso por Mes')
plt.ylabel('Tasa de Retraso [%]', fontsize=12)
plt.xlabel('Meses', fontsize=12)
plt.xticks(rotation=90)
plt.ylim(0,35)
plt.show()

# %%
tasas_dias = calcular_tasa(df, 'DIANOM')
tasas_dias
# Out:
#            Tasa (%)
# Viernes        22.0
# Jueves         20.0
# Lunes          20.0
# Domingo        16.0
# Miercoles      17.0
# Martes         17.0
# Sabado         16.0

# %%
tasas_dias_values = df['DIANOM'].value_counts().index

sns.set(style="darkgrid")
plt.figure(figsize = (8,6))
sns.barplot(x=tasas_dias_values, y=tasas_dias['Tasa (%)'], color = 'blue', alpha = 0.75)
plt.title('Tasa de Retraso por Día')
plt.ylabel('Tasa de Retraso [%]', fontsize=12)
plt.xlabel('Días', fontsize=12)
plt.xticks(rotation=90)
plt.ylim(0,35)
plt.show()

# %%
tasas_temporada = calcular_tasa(df, 'temporada_alta')
tasas_temporada
# Out:
#    Tasa (%)
# 0      18.0
# 1      20.0

# %%
tasas_temporada_values = df['temporada_alta'].value_counts().index

plt.figure(figsize = (8, 5))
sns.set(style="darkgrid")
sns.barplot(x=tasas_temporada_values, y=tasas_temporada['Tasa (%)'])
plt.title('Tasa de Retraso por Temporada')
plt.ylabel('Tasa de Retraso [%]', fontsize=12)
plt.xlabel('Temporada', fontsize=12)
plt.xticks(rotation=90)
plt.ylim(0,35)
plt.show()

# %%
tasas_tipovuelo = calcular_tasa(df, 'TIPOVUELO')
tasas_tipovuelo
# Out:
#    Tasa (%)
# N      15.0
# I      23.0

# %%
tasas_tipovuelo_values = df['TIPOVUELO'].value_counts().index

plt.figure(figsize = (5,5))
sns.set(style="darkgrid")
sns.barplot(x=tasas_tipovuelo_values, y=tasas_tipovuelo['Tasa (%)'])
plt.title('Tasa de Retraso por Tipo de Vuelo')
plt.ylabel('Tasa de Retraso [%]', fontsize=12)
plt.xlabel('Tipo de Vuelo', fontsize=12)
plt.ylim(0,35)
plt.show()

# %%
tasa_periododia = calcular_tasa(df, 'periodo_dia')
tasa_periododia
# Out:
#         Tasa (%)
# tarde       20.0
# mañana      16.0
# noche       20.0

# %%
tasas_periodo_values = df['periodo_dia'].value_counts().index

plt.figure(figsize = (5,5))
sns.set(style="darkgrid")
sns.barplot(x=tasas_periodo_values, y=tasa_periododia['Tasa (%)'])
plt.title('Tasa de Retraso por Periodo')
plt.ylabel('Tasa de Retraso [%]', fontsize=12)
plt.xlabel('Tipo de Periodo', fontsize=12)
plt.ylim(0,35)
plt.show()

# %% [markdown]
# * ¿Qué variables esperarías que más influyeran en predecir atrasos?

# %% [markdown]
# Me parece que las que más podrían influir serían:
# * **Aerolíneas**: Dependiendo de la calidad de gestión de cada aerolínea puede ser que afecte en sus programaciones. También puede que afecte el tipo de aerolínea, si es una low cost por ejemplo, estas llevan menos equipaje ya que es un costo extra para cada pasajero por lo que el tiempo de carga es menor, corriendo menor riesgo de retraso.
# * **Tipo de Vuelo**: esto puede afectar en cómo esté el clima del país de destino. Por ejemplo si se tiene que volar a argentina y se tiene que cruzar por la cordillera y hay un mal clima, es posible que se tenga que esperar un rato para poder salir.
# * **Mes**: Esto va un poco de la mano con lo anterior, si es que es un mes del año donde el clima no es lo suficientemente adecuado, se tendría que esperar.

# %% [markdown]
# ### 4. Entrena uno o varios modelos (usando el/los algoritmo(s) que prefieras) para estimar la probabilidad de atraso de un vuelo. Siéntete libre de generar variables adicionales y/o complementar con variables externas.

# %%
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay, roc_auc_score

# %%
data = shuffle(df[['OPERA', 'MES', 'TIPOVUELO', 'SIGLADES', 'DIANOM', 'atraso_15']], random_state = 111)

# %%
features = pd.concat([pd.get_dummies(data['OPERA'], prefix = 'OPERA'),pd.get_dummies(data['TIPOVUELO'], prefix = 'TIPOVUELO'), pd.get_dummies(data['MES'], prefix = 'MES')], axis = 1)
label = data['atraso_15']

# %%
x_train, x_test, y_train, y_test = train_test_split(features, label, test_size = 0.33, random_state = 42)

# %%
x_train.shape, x_test.shape
# Out:
# ((45698, 37), (22508, 37))

# %%
y_train.value_counts('%')
# Out:
# 0    0.813799
# 1    0.186201
# Name: atraso_15, dtype: float64

# %%
y_test.value_counts('%')
# Out:
# 0    0.81762
# 1    0.18238
# Name: atraso_15, dtype: float64

# %% [markdown]
# #### Utilizando Regresión logística

# %%
logReg = LogisticRegression()
model = logReg.fit(x_train, y_train)

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# #### Métricas Regresión Logística

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[18311,    92],
#        [ 3985,   120]], dtype=int64)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90     18403
#            1       0.57      0.03      0.06      4105
#
#     accuracy                           0.82     22508
#    macro avg       0.69      0.51      0.48     22508
# weighted avg       0.77      0.82      0.75     22508

# %% [markdown]
# #### Utilizando XGBoost

# %%
import xgboost as xgb
from xgboost import plot_importance

# %%
modelxgb = xgb.XGBClassifier(random_state=1, learning_rate=0.01)
modelxgb = modelxgb.fit(x_train, y_train)

# %%
y_predxgb = modelxgb.predict(x_test)
y_pred_proba = modelxgb.predict_proba(x_test)[:, 1]

# %% [markdown]
# #### Métricas XGBoost

# %%
cm=confusion_matrix(y_test, y_predxgb, normalize="true")
disp=ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=modelxgb.classes_)
disp.plot()
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90     18403
#            1       0.57      0.03      0.06      4105
#
#     accuracy                           0.82     22508
#    macro avg       0.69      0.51      0.48     22508
# weighted avg       0.77      0.82      0.75     22508

# %%
roc_auc = roc_auc_score(y_test, y_pred_proba)
print("ROC-AUC score:", roc_auc)
# Out:
# ROC-AUC score: 0.6502442109641209

# %% [markdown]
# #### Utilizando XGBoost dejando Features más importantes

# %%
modelxgb.feature_importances_
# Out:
# array([0.01000503, 0.03812765, 0.07740478, 0.        , 0.        ,
#        0.0532625 , 0.        , 0.        , 0.        , 0.11452045,
#        0.        , 0.05899748, 0.00510735, 0.        , 0.00056586,
#        0.        , 0.        , 0.0343819 , 0.        , 0.00872515,
#        0.06874514, 0.03494435, 0.02305366, 0.17575087, 0.        ,
#        0.01610018, 0.00777404, 0.0238743 , 0.00835021, 0.01279222,
#        0.01183943, 0.06969909, 0.00991499, 0.01740216, 0.03937674,
#        0.02739281, 0.05189165], dtype=float32)

# %%
plt.figure(figsize = (13,10))
plot_importance(modelxgb)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
features_importantes = features[['MES_7', 'TIPOVUELO_I', 'OPERA_Copa Air', 'OPERA_Latin American Wings',
                                'MES_12', 'OPERA_Grupo LATAM', 'MES_10', 'OPERA_JetSmart SPA', 'OPERA_Air Canada',
                                'MES_9', 'OPERA_American Airlines']]
labels_ = label

# %%
x_train2, x_test2, y_train2, y_test2 = train_test_split(features_importantes, labels_, test_size = 0.33, random_state = 42)

# %%
modelxgb = xgb.XGBClassifier(random_state=1, learning_rate=0.01, subsample = 1, max_depth = 10)
modelxgb = modelxgb.fit(x_train2, y_train2)

# %%
y_predxgb = modelxgb.predict(x_test2)
y_pred_proba = modelxgb.predict_proba(x_test2)[:, 1]

# %% [markdown]
# #### Métricas XGBoost dejando Features más importantes

# %%
cm=confusion_matrix(y_test2, y_predxgb, normalize="true")
disp=ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=modelxgb.classes_)
disp.plot()
plt.show()

# %%
print(classification_report(y_test2, y_predxgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      1.00      0.90     18403
#            1       0.66      0.01      0.03      4105
#
#     accuracy                           0.82     22508
#    macro avg       0.74      0.51      0.46     22508
# weighted avg       0.79      0.82      0.74     22508

# %%
roc_auc = roc_auc_score(y_test2, y_pred_proba)
print("ROC-AUC score:", roc_auc)
# Out:
# ROC-AUC score: 0.6404792471809427

# %% [markdown]
# ### 5. Evalúa tu modelo. ¿Qué performance tiene? ¿Qué métricas usaste para evaluar esa performance y por qué? ¿Por qué elegiste ese algoritmo en particular? ¿Qué variables son las que más influyen en la predicción? ¿Cómo podrías mejorar laperformance?

# %% [markdown]
# Los modelos utilizados en la sección anterior fueron:
# * **Regresión Logística**: Fue seleccionado ya que es el modelo más simple para poder resolver problemas de clasificación.
# * **XGBoost**: Fue seleccionado porque en general tiene un gran desempeño y entrega buenos resultados ya sea para regresión y clasificación, además es bastante rápido y facilita el tuneo de hiperparámetros.
#
# Los resultados obtenidos con ambos modelos fueron muy malos. Se utilizó matriz de confusión para validar los resultados. La cantidad de falsos negativos fue muy alta. Una de las posibles razones, la más clara, es el desbalanceo que existe en la clase 'atraso_15'. Del total de datos un 82% corresponde a no atraso y el 18% restante a atraso.
# Para poder mejorar la performance se tomaron dos decisiones, la primera aplicar un Grid Search CV sobre XGBoost para tunear de mejor manera los hiperparámetros y la segunda realizar un upsampling de la clase desbalanceada, en este caso los atrasos.

# %% [markdown]
# ### Grid Search CV

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {
                'learning_rate': [0.01,0.05, 0.1],
                'n_estimators': [50, 100, 150],
                'subsample': [0.5, 0.9]
}

modelxgb_GridCV = GridSearchCV(modelxgb, param_grid = parameters,
    cv = 2, n_jobs=-1, verbose=1).fit(x_train, y_train)
# Out:
# Fitting 2 folds for each of 18 candidates, totalling 36 fits

# %%
# Get the best parameters
best_params = modelxgb_GridCV.best_params_
print("Best parameters:", best_params)
# Out:
# Best parameters: {'learning_rate': 0.1, 'n_estimators': 100, 'subsample': 0.5}

# %%
y_predxgb_grid = modelxgb_GridCV.predict(x_test)
best_GridCV = modelxgb_GridCV.best_estimator_
y_pred_proba = best_GridCV.predict_proba(x_test)[:, 1]

# %%
cm=confusion_matrix(y_test, y_predxgb_grid, normalize="true")
disp=ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=modelxgb.classes_)
disp.plot()
plt.show()

# %%
roc_auc = roc_auc_score(y_test2, y_pred_proba)
print("ROC-AUC score:", roc_auc)
# Out:
# ROC-AUC score: 0.6687564974280328

# %% [markdown]
# ### Upsampling

# %% [markdown]
# El upsampling se debe hacer después de separar las particiones de test y de train

# %%
data_train, data_test = train_test_split(data, test_size = 0.33, random_state = 42)

# %%
data_train['atraso_15'].value_counts()
# Out:
# 0    37189
# 1     8509
# Name: atraso_15, dtype: int64

# %%
#Resample
from sklearn.utils import resample

data_train_no_retraso = data_train[data_train['atraso_15'] == 0]
data_train_atraso = data_train[data_train['atraso_15'] == 1]

data_train_atraso_upsampled = resample(data_train_atraso, 
                                 replace = True,     # sample with replacement
                                 n_samples = 30000,    # to match majority class
                                 random_state = 42) # reproducible results

data_train_upsampled = pd.concat([data_train_no_retraso, data_train_atraso_upsampled])

# %%
data_train_upsampled['atraso_15'].value_counts()
# Out:
# 0    37189
# 1    30000
# Name: atraso_15, dtype: int64

# %%
x_upsampled_train = pd.concat([pd.get_dummies(data_train_upsampled['OPERA'], prefix = 'OPERA'),pd.get_dummies(data_train_upsampled['TIPOVUELO'], prefix = 'TIPOVUELO'), pd.get_dummies(data_train_upsampled['MES'], prefix = 'MES')], axis = 1)
y_upsampled_train = data_train_upsampled['atraso_15']
x_upsampled_test = pd.concat([pd.get_dummies(data_test['OPERA'], prefix = 'OPERA'),pd.get_dummies(data_test['TIPOVUELO'], prefix = 'TIPOVUELO'), pd.get_dummies(data_test['MES'], prefix = 'MES')], axis = 1)
y_upsampled_test = data_test['atraso_15']

# %%
modelxgb = xgb.XGBClassifier(random_state=1, learning_rate=0.01, subsample = 1, max_depth = 10)
modelxgb.fit(x_upsampled_train, y_upsampled_train, verbose=False)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=1, ...)

# %%
y_upsampled_predxgb = modelxgb.predict(x_upsampled_test)
y_pred_proba = modelxgb.predict_proba(x_upsampled_test)[:, 1]

# %%
cm=confusion_matrix(y_upsampled_test, y_upsampled_predxgb, normalize="true")
disp=ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=modelxgb.classes_)
disp.plot()
plt.show()

# %%
modelxgb.score(x_upsampled_test, y_upsampled_test)
# Out:
# 0.6658077128132219

# %%
print(classification_report(y_upsampled_test, y_upsampled_predxgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.70      0.77     18403
#            1       0.28      0.53      0.36      4105
#
#     accuracy                           0.67     22508
#    macro avg       0.57      0.61      0.57     22508
# weighted avg       0.76      0.67      0.70     22508

# %%
roc_auc = roc_auc_score(y_upsampled_test, y_pred_proba)
print("ROC-AUC score:", roc_auc)
# Out:
# ROC-AUC score: 0.6624747209634504

# %% [markdown]
# Observando los dos métodos para incrementar la performance, se puede ver como el modelo no mejoró. Esto puede ser ya que la data creada al upsamplear no aporta más información. Si se pudiese pudiese balancear la clase tal vez los modelos tendrían un mejor desempeño.

# %% [markdown]
# # Trabajo Nicolás

# %% [markdown]
# ## 1. Escoge el modelo que a tu criterio tenga una mejor performance, argumentando tu decisión.

# %% [markdown]
# Se observa que la información entregada por los modelos implementados por Juan sobre los atrasos es casi nula, pues el modelo posee un sesgo que lo lleva a "predecir" casi el 100% de las veces que no habrá atraso (clase 0) y con esto alcanza un accuracy de casi 82%, el cuál es parecido a la tasa de "no atrasos" de la partición de test.
#
# No obstante, los modelos si son capaces de entregar información sobre los atrasos si se cambia el umbral de desición. Esto se ve mejor reflejado en la curva ROC que grafica el efecto de este cambio de umbral en el "true positive rate" y en el "false positive rate". Es por esto que se elige el ROC-AUC como métrica para determinar el mejor modelo.
#
# Dado lo anterior se observa que el mejor modelo se obtiene con XGBClassifier utilizando Grid Search, con las features originales y sin upsampling:
#
# **Best parameters: {'learning_rate': 0.05, 'n_estimators': 50, 'subsample': 0.9}**

# %% [markdown]
# ## 2. Implementa cambios sobre el modelo escogiendo la o las técnicas que prefieras buscando mejorar los resultados. Te recomendamos dejar los intentos que no lograron mejorar los resultados.

# %% [markdown]
# ### 2.1 Uso de otras features
# Al observar lso resultados obtenidos por Juan se logra notar que existen otras características del dataset que presentan una varianza considerable entre sus tasas de atraso.
#
# Las nuevas features a incluir son:
#
# **-SIGLADES**
#
# **-DIANOM**
#
# Además, debido a que existen destinos que poseen muy pocos vuelos (<10) y esto puede generar problemas al momento de codificar los features (one hot encoding) se les cabia la etiqueta de destino a "Others" para agruparlos.

# %%
menores_10_vuelos=data['SIGLADES'].value_counts().values<10
ciudades=data['SIGLADES'].value_counts().index
ciudades_others=list(ciudades[menores_10_vuelos])
data['SIGLADES'][data['SIGLADES'].isin(ciudades_others)]="Others"

# %%
data_train, data_test = train_test_split(data, test_size = 0.33, random_state = 42)

# %%
x_train = pd.concat([pd.get_dummies(data_train['OPERA'], prefix = 'OPERA'),pd.get_dummies(data_train['TIPOVUELO'], prefix = 'TIPOVUELO'), pd.get_dummies(data_train['MES'], prefix = 'MES'), pd.get_dummies(data_train['SIGLADES'], prefix = 'SIGLADES'), pd.get_dummies(data_train['DIANOM'], prefix = 'DIANOM')], axis = 1)
y_train = data_train['atraso_15']
x_test =  pd.concat([pd.get_dummies(data_test['OPERA'], prefix = 'OPERA'),pd.get_dummies(data_test['TIPOVUELO'], prefix = 'TIPOVUELO'), pd.get_dummies(data_test['MES'], prefix = 'MES'), pd.get_dummies(data_test['SIGLADES'], prefix = 'SIGLADES'), pd.get_dummies(data_test['DIANOM'], prefix = 'DIANOM')], axis = 1)
y_test = data_test['atraso_15']

# %%
modelxgb = xgb.XGBClassifier(learning_rate= 0.05, n_estimators = 50, subsample = 0.9,random_state=1, max_depth = 10)
modelxgb.fit(x_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=50, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=1, ...)

# %%
y_predxgb = modelxgb.predict(x_test)
y_pred_proba = modelxgb.predict_proba(x_test)[:, 1]

# %%
cm=confusion_matrix(y_test, y_predxgb, normalize="true")
disp=ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=modelxgb.classes_)
disp.plot()
plt.show()

# %%
roc_auc = roc_auc_score(y_test, y_pred_proba)
print("ROC-AUC score:", roc_auc)
# Out:
# ROC-AUC score: 0.6851047362068211

# %% [markdown]
# Se verifica la importancia de las nuevas features agregadas:

# %%
plt.figure(figsize = (13,30))
plot_importance(modelxgb, max_num_features=20)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# **Conclusión experimento "Uso de otras features"**
#
# En la gráfico de importancias se observa que las nuevas features utilizadas mejoran el rendimiento e incluso están entre las que más relevancia tienen para el modelo. Por lo tanto se concluye que el resultado del experimento es favorabl, con un aumento de ROC-AUC.

# %% [markdown]
# ### 2.2 Utilizando partición de validation con ROC-AUC

# %% [markdown]
# Puede que exista overfitting, por lo que se crea una partición de validación a partir de train set con el fin de evitar esto.

# %%
#Se elige que la partición de val sea un 10% de la antigua partición de train
data_train, data_val = train_test_split(data_train, test_size = 0.1, random_state = 42)

# %% [markdown]
# Se crea la partición de validación:

# %%
x_train = pd.concat([pd.get_dummies(data_train['OPERA'], prefix = 'OPERA'),pd.get_dummies(data_train['TIPOVUELO'], prefix = 'TIPOVUELO'), pd.get_dummies(data_train['MES'], prefix = 'MES'), pd.get_dummies(data_train['SIGLADES'], prefix = 'SIGLADES'), pd.get_dummies(data_train['DIANOM'], prefix = 'DIANOM')], axis = 1)
y_train = data_train['atraso_15']
x_val =  pd.concat([pd.get_dummies(data_val['OPERA'], prefix = 'OPERA'),pd.get_dummies(data_val['TIPOVUELO'], prefix = 'TIPOVUELO'), pd.get_dummies(data_val['MES'], prefix = 'MES'), pd.get_dummies(data_val['SIGLADES'], prefix = 'SIGLADES'), pd.get_dummies(data_val['DIANOM'], prefix = 'DIANOM')], axis = 1)
y_val = data_val['atraso_15']
eval_set = [(x_val, y_val)]

# %% [markdown]
# Se utiliza la nueva partición val durante el fit utilizando "early_stopping_rounds=10" y "eval_metric='auc'"

# %%
modelxgb = xgb.XGBClassifier(learning_rate= 0.05, n_estimators = 50, subsample = 0.9,random_state=1, max_depth = 10, eval_metric='auc', early_stopping_rounds=10)
modelxgb.fit(x_train, y_train,eval_set=eval_set,verbose=False)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=50, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=1, ...)

# %%
y_predxgb = modelxgb.predict(x_test)
y_pred_proba = modelxgb.predict_proba(x_test)[:, 1]

# %%
cm=confusion_matrix(y_test, y_predxgb, normalize="true")
disp=ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=modelxgb.classes_)
disp.plot()
plt.show()

# %%
roc_auc = roc_auc_score(y_test, y_pred_proba)
print("ROC-AUC score:", roc_auc)
# Out:
# ROC-AUC score: 0.6851653959665925

# %% [markdown]
# ### 2.3 Utilizando pesos para abordar el desbalance de clases

# %% [markdown]
# El parámetro "scale_pos_weight" está diseñado específicamente para abordar situaciones en las que el número de muestras de la clase positiva es significativamente inferior al número de muestras de la clase negativa. Permite ajustar la importancia relativa de la clase positiva (clase 1) en el proceso de entrenamiento asignándole un peso mayor. Representa "número de muestras de clase negativa" dividido en el "número de muestras de clase positiva".

# %%
#Se calcula la relación entre el "número de muestras de clase negativa" y el "número de muestras de clase positiva".
prop=y_train.value_counts()
prop=prop.values
peso_positivo=prop[0]/prop[1]
peso_positivo
# Out:
# 4.3811330629334035

# %%
modelxgb_con_pesos = xgb.XGBClassifier(scale_pos_weight=peso_positivo,learning_rate= 0.05, n_estimators = 50, subsample = 0.9,random_state=1, max_depth = 10, eval_metric='auc', early_stopping_rounds=10)
modelxgb_con_pesos.fit(x_train, y_train,eval_set=eval_set,verbose=False)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=50, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=1, ...)

# %%
y_predxgb = modelxgb_con_pesos.predict(x_test)
y_pred_proba = modelxgb_con_pesos.predict_proba(x_test)[:, 1]

# %%
cm=confusion_matrix(y_test, y_predxgb, normalize="true")
disp=ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=modelxgb.classes_)
disp.plot()
plt.show()

# %%
roc_auc = roc_auc_score(y_test, y_pred_proba)
print("ROC-AUC score:", roc_auc)
# Out:
# ROC-AUC score: 0.6859687853414251

# %% [markdown]
# ### 2.4 Uso de otro tipo de codificación para las features (codificación de tasa de atraso)

# %% [markdown]
# Se observa que la forma de encodear las features (one hot encoding) puede no ser la óptima, debido a que para una sola feature agrega demasiados nodos de entrada. Se propone el uso de la tasa de atraso por feature para la codificación.
# Por ejemplo, si se tiene:
# |     **Aerolinea**     | **Tasa de atraso en Train[%]** |
# |:---------------------:|:----------------------:|
# |      Grupo LATAM      |          18          |
# |      Sky Airline      |          18          |
# | Aerolineas Argentinas |          24          |
# |        Copa Air       |           6          |
# |  Latin American Wings |          41          |
# |        Avianca        |          27          |
#
# Entonces la codificación para la feature "SIGLADES" sería:
#
# |     **Aerolinea**     |  **Feature SIGLADES**  |
# |:---------------------:|:----------------------:|
# |      Grupo LATAM      |          0.18          |
# |      Sky Airline      |          0.18          |
# | Aerolineas Argentinas |          0.24          |
# |        Copa Air       |          0.06          |
# |  Latin American Wings |          0.41          |
# |        Avianca        |          0.27          |
#
# Esto provoca que el modelo pueda servir para otras aerolineas, destinos, etc para los cuales no ha sido entrenado, ya que solo necesita su tasa de atraso para dar una predicción. Además, al reducir el número de nodos de entrada, se espera que el modelo generalice mejor.

# %%
import pickle
#Función para obtener diccionnario de atrasos dado un dataframe y el nombre de una columna
def get_dic_tasa_atrasos(df, columna):
    
    dic_atrasos = {}
    atrasos=df[df["atraso_15"]==1]
    total_atrasos=atrasos[columna].value_counts() #total de vuelos atrasado por elemento de la columna
    
    total_values = df[columna].value_counts() #total de vuelos por elemento de la columna
    
    dic_tasas = {}
    for name, total in total_values.iteritems():
        if name in total_atrasos.index:
            dic_tasas[name] = round( total_atrasos[name]/total, 2)
        else:
            dic_tasas[name] = 0
            
    return dic_tasas

def encode_to_features(features_train,features_val,features_test):
    #Se itera por las columnas de features_train
    for col_name in features_train.columns:
        if col_name == "atraso_15":
            continue
        #Se obtine los diccionarios para mapear utilizando solo train 
        dic_rates_train=get_dic_tasa_atrasos(features_train,col_name)

        #se mapea las etiquetas categóricas a números entre 0 y 1
        features_train[col_name]=features_train[col_name].map(dic_rates_train)
        #Se aplica el mismo mapeo obtenido a val:
        features_val[col_name]=features_val[col_name].map(dic_rates_train)
        #Se aplica el mismo mapeo obtenido a test:
        features_test[col_name]=features_test[col_name].map(dic_rates_train)

        #Se guarda el diccionario en caso de ser usado para codificar features en la API
        with open(col_name+'_dic.pickle', 'wb') as f:
            pickle.dump(dic_rates_train, f)


    return features_train.drop("atraso_15",axis=1),  features_val.drop("atraso_15",axis=1), features_test.drop("atraso_15",axis=1)

# %%
x_train_tasa, x_val_tasa, x_test_tasa = encode_to_features(data_train,data_val,data_test)
eval_set = [(x_val_tasa, y_val)]

# %%
x_train_tasa.head(10)
# Out:
#        OPERA   MES  TIPOVUELO  SIGLADES  DIANOM
# 14422   0.18  0.11       0.15      0.18    0.17
# 52710   0.18  0.23       0.15      0.18    0.20
# 31629   0.18  0.17       0.23      0.26    0.17
# 57385   0.18  0.20       0.15      0.14    0.17
# 6909    0.18  0.15       0.23      0.28    0.22
# 25262   0.18  0.16       0.15      0.16    0.22
# 25789   0.18  0.16       0.15      0.16    0.22
# 60573   0.18  0.20       0.23      0.23    0.20
# 57958   0.18  0.20       0.23      0.26    0.17
# 21478   0.18  0.12       0.23      0.26    0.20

# %%
modelxgb = xgb.XGBClassifier(scale_pos_weight=peso_positivo,learning_rate= 0.05, n_estimators = 50, subsample = 0.9,random_state=1, max_depth = 10, eval_metric='auc', early_stopping_rounds=10)
modelxgb.fit(x_train_tasa, y_train,eval_set=eval_set,verbose=False)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=10, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=50, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=1, ...)

# %%
y_predxgb = modelxgb.predict(x_test_tasa)
y_pred_proba = modelxgb.predict_proba(x_test_tasa)[:, 1]

# %%
cm=confusion_matrix(y_test, y_predxgb, normalize="true")
disp=ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=modelxgb.classes_)
disp.plot()
plt.show()

# %%
roc_auc = roc_auc_score(y_test, y_pred_proba)
print("ROC-AUC score:", roc_auc)
# Out:
# ROC-AUC score: 0.6728594004724247

# %% [markdown]
# **Conclusión experimento "Uso de otro tipo de codificación para las features"**
#
# Se observó que el rendimiento en términos de ROC-AUC no mejora con estos nuevos features. A pesar de lo anterior, se destaca la versatilidad de este nuevo tipo de codificación de features, pues se podría ocupar para destinos y aerolineas nuevas (que no están en el entrenamiento) necesitando solamente un aproximado de su tasa de retraso.

# %% [markdown]
# ## 3. Serializa el modelo seleccionado (punto 2) e implementa una API REST para poder predecir atrasos de nuevos vuelos.

# %% [markdown]
# ### 3.1 Serialización del modelo
#
# El modelo seleccionado es aquel que utiliza pesos y fue entrenado con las features 'OPERA', 'TIPOVUELO', 'MES', 'SIGLADES' y 'DIANOM'. A continuación se guarda el modelo y las columnas necesarias.

# %%
import pickle
with open('API/modelxgb_con_pesos.pickle', 'wb') as f:
    pickle.dump(modelxgb_con_pesos, f)

# %%
model_columns = list(x_train.columns)
with open('API/columns_modelxgb_con_pesos.pickle', 'wb') as f:
    pickle.dump(model_columns, f)

# %% [markdown]
# ### 3.2 API REST

# %% [markdown]
# La implementación de la API se realiza en el archivo "main.py" de la carpeta "API/".
